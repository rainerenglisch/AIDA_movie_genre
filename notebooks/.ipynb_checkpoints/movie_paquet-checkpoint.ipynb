# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval
#!pip install pandas pyarrow
import pyarrow



import pyarrow.parquet as pq

#movies = pq.read_table(source="../data/raw/df_90000_99999.parquet.gzip").to_pandas()
movies = pq.read_table(source="../data/raw/df.parquet.gzip").to_pandas()
movies
# Out:
#         adult      id                      original_title  popularity  video  \
# 380000  False  537245                         El Pescador       0.600  False
# 380001  False  537246               Der Herzog von Aleria       0.600  False
# 380002  False  537247   Wem nie durch Liebe Leid geschah!       0.600  False
# 380003  False  537250          ¿Por qué ya no me quieres?       1.400  False
# 380004  False  537251                               民暴の帝王       0.600  False
# ...       ...     ...                                 ...         ...    ...
# 19995   False   31791         Opeth: The Roundhouse Tapes       5.698   True
# 19996   False   31792     Ozzy Osbourne: Bark at the Moon       3.115  False
# 19997   False   31793  Rob Zombie: Past, Present & Future       2.570  False
# 19998   False   31794   Rotting Christ: In Domine Sathana       0.600  False
# 19999   False   31795               Sarah Brightman: Diva       2.923  False
#
#                                             url  \
# 380000  https://www.themoviedb.org/movie/537245
# 380001  https://www.themoviedb.org/movie/537246
# 380002  https://www.themoviedb.org/movie/537247
# 380003  https://www.themoviedb.org/movie/537250
# 380004  https://www.themoviedb.org/movie/537251
# ...                                         ...
# 19995    https://www.themoviedb.org/movie/31791
# 19996    https://www.themoviedb.org/movie/31792
# 19997    https://www.themoviedb.org/movie/31793
# 19998    https://www.themoviedb.org/movie/31794
# 19999    https://www.themoviedb.org/movie/31795
#
#                                                poster_url     genre_id
# 380000  https://www.themoviedb.org/t/p/w500//pOOabahFF...           []
# 380001                                               None         [18]
# 380002                                               None         [18]
# 380003  https://www.themoviedb.org/t/p/w500//8Y0aOxqSe...     [80, 18]
# 380004  https://www.themoviedb.org/t/p/w500//5ayhYaAfg...           []
# ...                                                   ...          ...
# 19995   https://www.themoviedb.org/t/p/w500//YaCzP9wPJ...      [10402]
# 19996   https://www.themoviedb.org/t/p/w500//vG0QdyICu...      [10402]
# 19997                                                None      [10402]
# 19998                                                None  [28, 10402]
# 19999   https://www.themoviedb.org/t/p/w500//nURFkGVZ0...      [10402]
#
# [587920 rows x 8 columns]

# %%
### Check null values
movies.isnull().sum()

# there are movies without genre
movies = movies.drop(movies[movies['genre_id']=='[]'].index)

movies[movies['genre_id']=='[]']
# Out:
# Empty DataFrame
# Columns: [adult, id, original_title, popularity, video, url, poster_url, genre_id, genre_ids2]
# Index: []

# %%
# Remove movies without poster url
movies = movies.drop(movies[movies['poster_url'].isna()].index)
movies[movies['poster_url'].isna()]
# Out:
# Empty DataFrame
# Columns: [adult, id, original_title, popularity, video, url, poster_url, genre_id, genre_ids2]
# Index: []

# %%
# The list is a list of integers  , reason why a I made this function .
map_gender={"28":"Action",
"12":"Adventure",
"16":"Animation",
"35":"Comedy",
"80":"Crime",
"99":"Documentary",
"18":"Drama",
"10751":"Family",
"14":"Fantasy",
"36":	"History",
"27":"Horror",
"10402"	:"Music",
"9648":"Mystery",
"10749":"Romance",
"878"	:"Science Fiction",
"10770":"TV Movie",
"53":"Thriller",
"10752":"War",
"37":"Western" }

def map_multiclass(x):
  tmp=[]

  for y in x.split(","):
    y=y.replace('[', '') 
    y=y.replace(']', '') 
    y=y.replace(' ', '') 

    if y in map_gender:
     tmp.append(map_gender[y])

  return ','.join(tmp)


movies['genre_ids2']=movies['genre_id'].apply(lambda x: map_multiclass(x))
movies
# Out:
#         adult      id                                     original_title  \
# 380003  False  537250                         ¿Por qué ya no me quieres?
# 380010  False  537266                                            Success
# 380017  False  537274                                  Предел возможного
# 380020  False  537277                                                 母親
# 380022  False  537281                                   1+1=3 Ora Tinjon
# ...       ...     ...                                                ...
# 19993   False   31788  Bill Hicks Live: Satirist, Social Critic, Stan...
# 19994   False   31789                                       Pédale douce
# 19995   False   31791                        Opeth: The Roundhouse Tapes
# 19996   False   31792                    Ozzy Osbourne: Bark at the Moon
# 19999   False   31795                              Sarah Brightman: Diva
#
#         popularity  video                                      url  \
# 380003       1.400  False  https://www.themoviedb.org/movie/537250
# 380010       0.600  False  https://www.themoviedb.org/movie/537266
# 380017       0.620  False  https://www.themoviedb.org/movie/537274
# 380020       0.600  False  https://www.themoviedb.org/movie/537277
# 380022       0.600  False  https://www.themoviedb.org/movie/537281
# ...            ...    ...                                      ...
# 19993        5.355  False   https://www.themoviedb.org/movie/31788
# 19994        6.775  False   https://www.themoviedb.org/movie/31789
# 19995        5.698   True   https://www.themoviedb.org/movie/31791
# 19996        3.115  False   https://www.themoviedb.org/movie/31792
# 19999        2.923  False   https://www.themoviedb.org/movie/31795
#
#                                                poster_url  genre_id  \
# 380003  https://www.themoviedb.org/t/p/w500//8Y0aOxqSe...  [80, 18]
# 380010  https://www.themoviedb.org/t/p/w500//tJMm1JJUe...      [18]
# 380017  https://www.themoviedb.org/t/p/w500//h9aXCUZ6g...      [18]
# 380020  https://www.themoviedb.org/t/p/w500//3Ogn8SWj2...      [18]
# 380022  https://www.themoviedb.org/t/p/w500//47yYJPL2q...      [18]
# ...                                                   ...       ...
# 19993   https://www.themoviedb.org/t/p/w500//lz2poVfHS...      [35]
# 19994   https://www.themoviedb.org/t/p/w500//xYFrGGsmK...      [35]
# 19995   https://www.themoviedb.org/t/p/w500//YaCzP9wPJ...   [10402]
# 19996   https://www.themoviedb.org/t/p/w500//vG0QdyICu...   [10402]
# 19999   https://www.themoviedb.org/t/p/w500//nURFkGVZ0...   [10402]
#
#          genre_ids2
# 380003  Crime,Drama
# 380010        Drama
# 380017        Drama
# 380020        Drama
# 380022        Drama
# ...             ...
# 19993        Comedy
# 19994        Comedy
# 19995         Music
# 19996         Music
# 19999         Music
#
# [281578 rows x 9 columns]

# %%
## Dist of genres

## Toop 30 multiclasses
top30 = pd.DataFrame(movies.genre_ids2.value_counts(normalize=True).sort_values(ascending=False)[0:30]).reset_index().rename(columns={'index': 'Multiclass'})
top30
# Out:
#               Multiclass  genre_ids2
# 0            Documentary    0.148904
# 1                  Drama    0.148463
# 2                 Comedy    0.096382
# 3                  Music    0.036604
# 4                 Horror    0.028102
# 5              Animation    0.026877
# 6          Drama,Romance    0.019391
# 7           Comedy,Drama    0.017448
# 8                 Action    0.012842
# 9               Thriller    0.011634
# 10        Comedy,Romance    0.011613
# 11          Drama,Comedy    0.011127
# 12               Western    0.007994
# 13               Romance    0.007976
# 14         Romance,Drama    0.007714
# 15     Documentary,Music    0.007426
# 16        Drama,Thriller    0.007014
# 17           Crime,Drama    0.006510
# 18       Horror,Thriller    0.005927
# 19                 Crime    0.005885
# 20                Family    0.005775
# 21          Action,Drama    0.005775
# 22       Science Fiction    0.004915
# 23        Romance,Comedy    0.004798
# 24           Drama,Crime    0.004667
# 25     Music,Documentary    0.004624
# 26  Comedy,Drama,Romance    0.004603
# 27         Drama,History    0.004500
# 28      Animation,Family    0.004361
# 29          Drama,Family    0.004120

# %%
plt.figure(figsize=(30,10)) 
plt.bar(top30.Multiclass, top30.genre_ids2)
plt.xticks(rotation=45)
plt.show()

# %%
## Review genre name  Explode the gender list in x rows to make a class and not multiclass

#movies= pd.read_csv('movies - movies.csv')

#movies = pq.read_table(source="../data/raw/df_90000_99999.parquet.gzip").to_pandas()
movies = pq.read_table(source="../data/raw/df.parquet.gzip").to_pandas()
movies


movies['genre_id'] = movies['genre_id'].apply(literal_eval) #convert to list type type was extrange in the excel
movie_genre = movies.explode('genre_id')
movie_genre[movie_genre.original_title=='Submarine D-1']

# the movie is x times depend on the gender
# Out:
#        adult      id original_title  popularity  video  \
# 99995  False  162785  Submarine D-1       2.423  False
# 99995  False  162785  Submarine D-1       2.423  False
#
#                                            url  \
# 99995  https://www.themoviedb.org/movie/162785
# 99995  https://www.themoviedb.org/movie/162785
#
#                                               poster_url genre_id
# 99995  https://www.themoviedb.org/t/p/w500//wv6J5QCTo...       28
# 99995  https://www.themoviedb.org/t/p/w500//wv6J5QCTo...       18

# %%
movie_genre.shape
# Out:
# (813268, 8)

# %%
## merge both datasets

genre_list= pd.read_csv('../data/raw/movie_genres - movie_genres.csv')

movie_genre_name=pd.merge(movie_genre,genre_list,left_on='genre_id', right_on='id')

movie_genre_name[movie_genre_name.original_title=='Submarine D-1']
# Out:
#         adult    id_x original_title  popularity  video  \
# 57189   False  162785  Submarine D-1       2.423  False
# 423219  False  162785  Submarine D-1       2.423  False
#
#                                             url  \
# 57189   https://www.themoviedb.org/movie/162785
# 423219  https://www.themoviedb.org/movie/162785
#
#                                                poster_url genre_id  id_y  \
# 57189   https://www.themoviedb.org/t/p/w500//wv6J5QCTo...       18    18
# 423219  https://www.themoviedb.org/t/p/w500//wv6J5QCTo...       28    28
#
#           name
# 57189    Drama
# 423219  Action

# %%
## Check nulls  note poster can have null values but not the gender

movie_genre_name.isnull().sum()
# Out:
# adult                  0
# id_x                   0
# original_title         0
# popularity             0
# video                  0
# url                40919
# poster_url        148070
# genre_id               0
# id_y                   0
# name                   0
# dtype: int64

# %%
top30_separateClass=pd.DataFrame(movie_genre_name.name.value_counts()).reset_index().rename(columns={'index': 'class_'})
top30_separateClass
# Out:
#              class_    name
# 0             Drama  136060
# 1            Comedy   89036
# 2       Documentary   82819
# 3           Romance   32923
# 4            Action   30130
# 5          Thriller   29408
# 6             Music   29013
# 7         Animation   28574
# 8            Horror   28245
# 9             Crime   21651
# 10           Family   18881
# 11        Adventure   16147
# 12  Science Fiction   13067
# 13          Fantasy   12803
# 14         TV Movie   12082
# 15          Mystery   11480
# 16          History    9647
# 17              War    7192
# 18          Western    5909

# %%
plt.figure(figsize=(30,10)) 
plt.bar(top30_separateClass.class_,top30_separateClass.name)
plt.xticks(rotation=45)
plt.show()
